# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
DQ=os.listdir("H:/DQ Salman")

# %%
VJD=os.listdir("H:/VJD")

# %%
KA=os.listdir("H:/Kartik Aaryan")

# %%
limit=10
DQ_images=[None]*limit
j=0
for i in DQ:
    if(j<limit):
        DQ_images[j]=imread("H:/DQ Salman/"+i)
        j+=1
    else:
         break

# %%
limit=10
VJD_images=[None]*limit
j=0
for i in VJD:
    if(j<limit):
        VJD_images[j]=imread("H:/VJD/"+i)
        j+=1
    else:
         break

# %%
limit=10
KA_images=[None]*limit
j=0
for i in KA:
    if(j<limit):
        KA_images[j]=imread("H:/Kartik Aaryan/"+i)
        j+=1
    else:
         break

# %%
imshow(DQ_images[0])

# %%
imshow(VJD_images[1])

# %%
imshow(KA_images[3])

# %%
DQ_images[7].shape
# Out:
# (200, 200, 3)

# %%
VJD_images[9].shape
# Out:
# (176, 286, 3)

# %%
KA_images[4].shape
# Out:
# (168, 300, 3)

# %%
DQ_gray=[None]*limit
j=0
for i in DQ:
    if(j<limit):
        DQ_gray[j]=rgb2gray(DQ_images[j])
        j+=1
    else:
        break

# %%
VJD_gray=[None]*limit
j=0
for i in VJD:
    if(j<limit):
        VJD_gray[j]=rgb2gray(VJD_images[j])
        j+=1
    else:
        break

# %%
KA_gray=[None]*limit
j=0
for i in KA:
    if(j<limit):
        KA_gray[j]=rgb2gray(KA_images[j])
        j+=1
    else:
        break

# %%
imshow(DQ_gray[2])

# %%
imshow(VJD_gray[4])

# %%
imshow(KA_gray[9])

# %%
DQ_gray[0].shape
# Out:
# (168, 300)

# %%
VJD_gray[1].shape
# Out:
# (204, 247)

# %%
KA_gray[2].shape
# Out:
# (194, 259)

# %%
for j in range (10):
    DQ=DQ_gray[j]
    DQ_gray[j]=resize(DQ,(512,512))

# %%
for j in range (10):
    VJD=VJD_gray[j]
    VJD_gray[j]=resize(VJD,(512,512))

# %%
for j in range (10):
    KA=KA_gray[j]
    KA_gray[j]=resize(KA,(512,512))

# %%
imshow(DQ_gray[1])

# %%
imshow(VJD_gray[5])

# %%
imshow(KA_gray[2])

# %%
DQ_gray[0].shape
# Out:
# (512, 512)

# %%
VJD_gray[0].shape
# Out:
# (512, 512)

# %%
KA_gray[0].shape
# Out:
# (512, 512)

# %%
len_of_images_DQ=len(DQ_gray)

# %%
len_of_images_VJD=len(VJD_gray)

# %%
len_of_images_KA=len(KA_gray)

# %%
image_size_DQ=DQ_gray[7].shape
image_size_DQ
# Out:
# (512, 512)

# %%
image_size_VJD=VJD_gray[7].shape
image_size_VJD
# Out:
# (512, 512)

# %%
image_size_KA=KA_gray[7].shape
image_size_KA
# Out:
# (512, 512)

# %%
flatten_size_DQ=image_size_DQ[0]*image_size_DQ[1]
flatten_size_DQ
# Out:
# 262144

# %%
flatten_size_VJD=image_size_VJD[0]*image_size_VJD[1]
flatten_size_VJD
# Out:
# 262144

# %%
flatten_size_KA=image_size_KA[0]*image_size_KA[1]
flatten_size_KA
# Out:
# 262144

# %%
for i in range(len_of_images_DQ):
    DQ_gray[i]=np.ndarray.flatten(DQ_gray[i]).reshape(flatten_size_DQ,1)

# %%
for i in range(len_of_images_VJD):
    VJD_gray[i]=np.ndarray.flatten(VJD_gray[i]).reshape(flatten_size_VJD,1)

# %%
for i in range(len_of_images_KA):
    KA_gray[i]=np.ndarray.flatten(KA_gray[i]).reshape(flatten_size_KA,1)

# %%
DQ_gray=np.dstack(DQ_gray)

# %%
VJD_gray=np.dstack(VJD_gray)

# %%
KA_gray=np.dstack(KA_gray)

# %%
DQ_gray=np.rollaxis(DQ_gray,axis=2,start=0)
DQ_gray.shape
# Out:
# (10, 262144, 1)

# %%
VJD_gray=np.rollaxis(VJD_gray,axis=2,start=0)
VJD_gray.shape
# Out:
# (10, 262144, 1)

# %%
KA_gray=np.rollaxis(KA_gray,axis=2,start=0)
KA_gray.shape
# Out:
# (10, 262144, 1)

# %%
DQ_gray=DQ_gray.reshape(len_of_images_DQ,flatten_size_DQ)

# %%
DQ_gray.shape
# Out:
# (10, 262144)

# %%
VJD_gray=VJD_gray.reshape(len_of_images_VJD,flatten_size_VJD)

# %%
VJD_gray.shape
# Out:
# (10, 262144)

# %%
KA_gray=KA_gray.reshape(len_of_images_KA,flatten_size_KA)

# %%
KA_gray.shape
# Out:
# (10, 262144)

# %%
DQ_gray=DQ_gray.reshape(len_of_images_DQ,flatten_size_DQ)
DQ_gray.shape
# Out:
# (10, 262144)

# %%
VJD_gray=VJD_gray.reshape(len_of_images_VJD,flatten_size_VJD)
VJD_gray.shape
# Out:
# (10, 262144)

# %%
KA_gray=KA_gray.reshape(len_of_images_KA,flatten_size_KA)
KA_gray.shape
# Out:
# (10, 262144)

# %%
DQ_data=pd.DataFrame(DQ_gray)
DQ_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.248108  0.248108  0.248108  0.248108  0.248644  0.250942  0.252030
# 1  0.485335  0.480795  0.489700  0.498605  0.502926  0.505597  0.505753
# 2  0.925788  0.925788  0.925788  0.925788  0.925788  0.925788  0.925788
# 3  0.488331  0.458149  0.532902  0.607656  0.512079  0.396385  0.337912
# 4  0.103762  0.103762  0.103762  0.103939  0.105670  0.107401  0.107684
# 5  0.706344  0.705502  0.702972  0.695768  0.688973  0.682835  0.674196
# 6  0.458530  0.458879  0.460367  0.463474  0.466891  0.470600  0.474309
# 7  0.986475  0.986475  0.986475  0.986475  0.986475  0.986475  0.986475
# 8  0.333885  0.333612  0.331954  0.329503  0.326785  0.325788  0.325328
# 9  0.495236  0.577313  0.894822  0.896477  0.865911  0.880379  0.881699
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.252030  0.252663  0.253520  ...  0.133639  0.133639  0.132398  0.125505
# ...

# %%
VJD_data=pd.DataFrame(VJD_gray)
VJD_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.869523  0.869523  0.869523  0.869523  0.868271  0.866685  0.865100
# 1  0.851248  0.851248  0.851248  0.851248  0.851248  0.851849  0.853741
# 2  0.122699  0.122713  0.122121  0.120903  0.118966  0.116435  0.113152
# 3  0.438948  0.449879  0.487882  0.530113  0.572721  0.615563  0.661036
# 4  0.704521  0.705105  0.730322  0.760493  0.794975  0.821305  0.841177
# 5  0.129086  0.129086  0.129086  0.129235  0.130958  0.132682  0.135411
# 6  0.206729  0.205442  0.198916  0.189032  0.178286  0.171024  0.164756
# 7  0.777051  0.777051  0.777051  0.777051  0.777051  0.777051  0.777051
# 8  0.050145  0.050834  0.053139  0.055760  0.059052  0.064332  0.067267
# 9  0.155356  0.156275  0.160656  0.168021  0.175962  0.179810  0.183360
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.863514  0.861929  0.860343  ...  0.605312  0.605567  0.606028  0.606488
# ...

# %%
KA_data=pd.DataFrame(KA_gray)
KA_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0
# 11  0.488331  0.458149  0.532902  0.607656  0.512079  0.396385  0.337912
# ...

# %%
celebs_indexed.to_csv("H:/celebs_indexed.csv")

# %%
pd.read_csv("H:/celebs_indexed.csv")
# Out:
#     Unnamed: 0         0         1         2         3         4         5  \
# 0            0  0.491996  0.491996  0.491996  0.494182  0.496488  0.498793
# 1            1  0.122218  0.122218  0.122218  0.122218  0.122218  0.122218
# 2            2  0.925788  0.925788  0.925788  0.925788  0.925788  0.925788
# 3            3  0.663560  0.663592  0.664960  0.665596  0.665596  0.665940
# 4            4  0.623085  0.623236  0.623955  0.625287  0.626776  0.628967
# 5            5  0.873600  0.873600  0.873600  0.873600  0.873600  0.873600
# 6            6  0.485335  0.480795  0.489700  0.498605  0.502926  0.505597
# 7            7  0.129086  0.129086  0.129086  0.129235  0.130958  0.132682
# 8            8  0.663388  0.706305  0.652511  0.598718  0.567124  0.586528
# 9            9  0.741683  0.742135  0.743679  0.743907  0.745185  0.750191
# 10          10  0.986475  0.986475  0.986475  0.986475  0.986475  0.986475
# ...

# %%
x=celebs_indexed.values[:,:-1]

# %%
y=celebs_indexed.values[:,-1]

# %%
x
# Out:
# array([[0.4919956862745098, 0.49199568627450974, 0.49199568627450974,
#         ..., 0.6056537788600548, 0.6064305185415231, 0.6066627662868126],
#        [0.12221803921568627, 0.12221803921568629, 0.12221803921568629,
#         ..., 0.045144770795036766, 0.043618891888786766,
#         0.04317130074295343],
#        [0.925787843137255, 0.9257878431372549, 0.9257878431372549, ...,
#         0.7798611776224772, 0.7831293557769177, 0.7822287911299162],
#        ...,
#        [0.7063443160232843, 0.7055017915134804, 0.7029724248332603, ...,
#         0.38098805759803933, 0.3786060110294118, 0.3777634865196079],
#        [0.8695231372549018, 0.8695231372549018, 0.8695231372549018, ...,
#         0.6062775386795342, 0.6064070722273284, 0.6063457471660538],
#        [0.7045209978096157, 0.7051051790588978, 0.7303223363195682, ...,
#         0.9451612247362323, 0.9445451735672297, 0.9445309021115771]],
#       dtype=object)

# %%
y
# Out:
# array(['Kartik Aaryan', 'Kartik Aaryan', 'DQ Salman', 'Kartik Aaryan',
#        'Kartik Aaryan', 'Kartik Aaryan', 'DQ Salman', 'VJ D',
#        'Kartik Aaryan', 'Kartik Aaryan', 'DQ Salman', 'DQ Salman',
#        'DQ Salman', 'VJ D', 'Kartik Aaryan', 'DQ Salman', 'DQ Salman',
#        'VJ D', 'DQ Salman', 'Kartik Aaryan', 'VJ D', 'DQ Salman', 'VJ D',
#        'VJ D', 'VJ D', 'Kartik Aaryan', 'VJ D', 'DQ Salman', 'VJ D',
#        'VJ D'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Kartik Aaryan', 'Kartik Aaryan', 'Kartik Aaryan', 'Kartik Aaryan',
#        'Kartik Aaryan', 'Kartik Aaryan'], dtype=object)

# %%
for i in (np.random.randint(0,6,35)):
    predicted_images = (np.reshape(x_test[i], (512,512)).astype(np.float64))
    plt.title('predicted label:{0}'. format(y_pred[i]))
    plt.imshow(predicted_images, interpolation='nearest', cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[0, 2, 0],
#        [0, 0, 0],
#        [0, 4, 0]], dtype=int64)
